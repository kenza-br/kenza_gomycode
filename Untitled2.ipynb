# %%
import pandas as pd 

data=pd.read_csv("titanic-passengers.csv",sep=";")
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop(['Cabin'],axis=1,inplace=True)
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum().sum()
# Out:
# 179

# %%
data['Age'].fillna(data['Age'].median(),inplace=True)
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Embarked'].fillna(data['Embarked'].mode().to_string(),inplace=True)
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.drop(columns=['Ticket'],axis=1,inplace=True)
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x='Sex',y='Age', data=data)

# %% [markdown]
# #interpretation:
# The box plot is comparatively short and this suggests that overall titanic passengers' age have are close.

# %%
c=sns.FacetGrid(data,row='Sex', col='Survived')
c.map(sns.distplot,'Age')

# %% [markdown]
# #inter

# %%
c=sns.FacetGrid(data, col='Survived')
c.map(sns.distplot,'Pclass')

# %%
#interpretation:

# %%
def plot_correlation_map(df):
    corr=df.corr()
    s,ax= plt.subplots(figsize =(12,10))
    cmap=sns.diverging_palette(220,10,as_cmap = True)
    s=sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={'shrink':.9}, ax=ax, annot= True, annot_kws ={'fontsize':12})
plot_correlation_map(data)

# %% [markdown]
# This fct is showing the correlation coeficient of each column of the data. It is used to summerize the data. It helps us understand our dataset, statical relationship between the columns and
# It helps us select the most important ones.

# %%
data['Survived']=encoder.fit_transform(data['Survived'])
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# we want to see the impact of Pclass on the variable Survived

# %%
data['Title']=data['Name'].str.extract(' ([A-Za-z]+)\.') 
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=data[["Sex","Survived","Pclass","Embarked"]].groupby(["Pclass","Sex","Embarked"],as_index=True).mean()
df
# Out:
#                         Survived
# Pclass Sex    Embarked
# 1      female 0    S    1.000000
#               C         0.976744
#               Q         1.000000
#               S         0.958333
#        male   C         0.404762
#               Q         0.000000
#               S         0.354430
# 2      female C         1.000000
#               Q         1.000000
#               S         0.910448
#        male   C         0.200000
#               Q         0.000000
#               S         0.154639
# 3      female C         0.652174
#               Q         0.727273
#               S         0.375000
#        male   C         0.232558
#               Q         0.076923
#               S         0.128302

# %% [markdown]
# we want to see the impact of Pclass, Sex and Embarked on the variable Survived

# %%
data['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Dr', 'Major', 'Don', 'Master', 'Rev', 'Col',
#        'Mlle', 'Lady', 'Jonkheer', 'Mme', 'Sir', 'Capt', 'Countess', 'Ms'],
#       dtype=object)

# %%
Title_Dictionary = {"Capt":"Officer", "Col":"Officer", "Major":"Officer","Dr":"Officer","Rev":"Officer",
                    "Jonkheer": "Royalty","Don":"Royalty","Sir" :"Royalty","Lady" :"Royalty","Countess": "Royalty",
                    "Dona":"Royalty","Mme":"Miss","Mlle":"Miss","Miss" :"Miss","Ms":"Mrs","Mr":"Mrs",
                    "Mrs":"Mrs", "Master":"Master"}

data.replace(Title_Dictionary, inplace=True)
data['Title'].value_counts()
# Out:
# Mrs        643
# Miss       185
# Master      40
# Officer     18
# Royalty      5
# Name: Title, dtype: int64

# %%
data['FamilySize']=data['Parch']+data['SibSp']
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[['FamilySize','Survived']].groupby(['FamilySize'],as_index=True).mean()
# Out:
#             Survived
# FamilySize
# 0           0.303538
# 1           0.552795
# 2           0.578431
# 3           0.724138
# 4           0.200000
# 5           0.136364
# 6           0.333333
# 7           0.000000
# 10          0.000000

# %% [markdown]
# we want to see the impact of FamilySize on the variable Survived
